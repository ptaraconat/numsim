# %%
import sys as sys 
sys.path.append('../')
from solver.hartree_fock import *

# %%
atom_types = [8, 1, 1]  # O, H, H
atom_positions = [np.array([0., 0., 0.]), 
                  np.array([1.43141111, 0.        , 1.1083169 ]), 
                  np.array([-1.43141111,  0.        ,  1.1083169 ])]
# Initialisation et résolution RHF
rhf = RestrictedHartreeFock(
    basis_functions='sto-3g',
    atom_coordinates=atom_positions,
    nuclei_charges=atom_types,
)
electronic_energy = rhf.solve(tol=1e-8)
nuclear_repulsion = nuclear_nuclear_repulsion_energy(atom_positions, atom_types)
print("Énergie électronique (Hartree) :", electronic_energy)
print("Énergie répulsion nucléaire (Hartree) :", nuclear_repulsion)
print("Énergie totale de la molécule (Hartree) :", electronic_energy + nuclear_repulsion)
# Out:
# Init overlapp integrals
# Advancement :  0.0
# Advancement :  14.285714285714285
# Advancement :  28.57142857142857
# Advancement :  42.857142857142854
# Advancement :  57.14285714285714
# Advancement :  71.42857142857143
# Advancement :  85.71428571428571
# Init core hamilatonian integrals (Kinetic and nuclear attraction)
# Advancement :  0.0
# Advancement :  14.285714285714285
# Advancement :  28.57142857142857
# Advancement :  42.857142857142854
# Advancement :  57.14285714285714
# Advancement :  71.42857142857143
# Advancement :  85.71428571428571
# Init electron electron repulsion integrals
# Advancement :  0.0
# Advancement :  14.285714285714285
# Advancement :  28.57142857142857
# Advancement :  42.857142857142854
# Advancement :  57.14285714285714
# Advancement :  71.42857142857143
# Advancement :  85.71428571428571
# #######################
# Hartree Fock Step :  0
# Convergence crit :  127.3574076153926
# electronic energy :  -127.3574076153926
# #######################
# Hartree Fock Step :  1
# Convergence crit :  46.96939513263948
# electronic energy :  -80.38801248275313
# #######################
# Hartree Fock Step :  2
# Convergence crit :  4.077664072200136
# electronic energy :  -84.46567655495326
# #######################
# Hartree Fock Step :  3
# Convergence crit :  0.3401524285580706
# electronic energy :  -84.12552412639519
# #######################
# Hartree Fock Step :  4
# Convergence crit :  0.02827594924505661
# electronic energy :  -84.15380007564025
# #######################
# Hartree Fock Step :  5
# Convergence crit :  0.0028639089014177443
# electronic energy :  -84.15093616673883
# #######################
# Hartree Fock Step :  6
# Convergence crit :  0.00015648482461472213
# electronic energy :  -84.15077968191422
# #######################
# Hartree Fock Step :  7
# Convergence crit :  0.00015945269775841098
# electronic energy :  -84.15062022921646
# #######################
# Hartree Fock Step :  8
# Convergence crit :  6.340893843059803e-05
# electronic energy :  -84.15055682027803
# #######################
# Hartree Fock Step :  9
# Convergence crit :  2.8074060679728063e-05
# electronic energy :  -84.15052874621735
# #######################
# Hartree Fock Step :  10
# Convergence crit :  1.2145785504458217e-05
# electronic energy :  -84.15051660043184
# #######################
# Hartree Fock Step :  11
# Convergence crit :  5.2693084597876805e-06
# electronic energy :  -84.15051133112338
# #######################
# Hartree Fock Step :  12
# Convergence crit :  2.2842513658360986e-06
# electronic energy :  -84.15050904687202
# #######################
# Hartree Fock Step :  13
# Convergence crit :  9.90335337291981e-07
# electronic energy :  -84.15050805653668
# #######################
# Hartree Fock Step :  14
# Convergence crit :  4.293697912771677e-07
# electronic energy :  -84.15050762716689
# #######################
# Hartree Fock Step :  15
# Convergence crit :  1.861658915913722e-07
# electronic energy :  -84.150507441001
# #######################
# Hartree Fock Step :  16
# Convergence crit :  8.071998536252067e-08
# electronic energy :  -84.15050736028101
# #######################
# Hartree Fock Step :  17
# Convergence crit :  3.500034040371247e-08
# electronic energy :  -84.15050732528067
# #######################
# Hartree Fock Step :  18
# Convergence crit :  1.5176254919424537e-08
# electronic energy :  -84.15050731010442
# HF loop converged at step  19
# electronic energy :  -84.1505073035238
# Énergie électronique (Hartree) : -84.1505073035238
# Énergie répulsion nucléaire (Hartree) : 9.187460599809516
# Énergie totale de la molécule (Hartree) : -74.96304670371428

# %%
from quantchem.hartree_fock_utils import * 
# Supposons que rhf est ton objet RestrictedHartreeFock avec les attributs :
# rhf.atom_coordinates, rhf.nuclei_charges, rhf.basis_functions, rhf.mos (coefficients MO)
# et que tu veux visualiser l'orbital occupé n°0 (le premier)

grid_points, shape, spacing, X, Y, Z = generate_grid(rhf.atom_coordinates, spacing=0.2, padding=3.0)
values = evaluate_mo_on_grid(grid_points, rhf.basis_functions, rhf.mos, orbital_index=2)  # Orbital 0

plot_orbital_volume(values, X, Y, Z,
                   atom_coords=rhf.atom_coordinates,
                   atom_charges=rhf.nuclei_charges,
                   iso_range=0.05)
